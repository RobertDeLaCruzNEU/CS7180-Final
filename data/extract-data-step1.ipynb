# %%
# !python -m pip install opencv-python
# !python -m pip install pydantic
from pie_data import PIE
pie_path = 'videos/'
save_path = 'images/'
imdb = PIE(data_path=pie_path)
imdb.extract_and_save_images(save_path=save_path, extract_frame_type='annotated')
# Out:
# PIE path: videos/
# Extracting frames from set01
# Generating annotated frame numbers for set01
# video_0001
# [####################] 99.95%
#
# video_0002
# [####################] 99.99%
#
# video_0003
# [####################] 99.99%
#
# video_0004
# [####################] 99.95%

# %%
db = imdb.generate_database()
# Out:
# ---------------------------------------------------------
# Generating database for pie
# Getting annotations for set01, video_0001
# videos/annotations\set01\video_0001_annt.xml
# Getting annotations for set01, video_0002
# videos/annotations\set01\video_0002_annt.xml
# Getting annotations for set01, video_0003
# videos/annotations\set01\video_0003_annt.xml
# Getting annotations for set01, video_0004
# videos/annotations\set01\video_0004_annt.xml
# The database is written to c:\Users\rober\OneDrive\Desktop\CS7150\CS7180-Final\data\videos\data_cache\pie_database.pkl
