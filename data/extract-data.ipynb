# %%
# !python -m pip install opencv-python
from pie_data import PIE
pie_path = 'videos/'
save_path = 'images/'
imdb = PIE(data_path=pie_path)
imdb.extract_and_save_images(save_path=save_path, extract_frame_type='annotated')
# Out:
# PIE path: videos/
# Extracting frames from set01
# Generating annotated frame numbers for set01
# video_0001
# [####################] 99.95%
#
# video_0002
# Failed to open the video video_0002
# num images don't match 6840/0
#
#
# video_0003
# Failed to open the video video_0003
# num images don't match 8043/0
#
#
# video_0004
# Failed to open the video video_0004
# num images don't match 2161/0
